# %% [markdown]
# ## Testing Your Code
# For this assignment, I created a Python program in VS Code called `calculator.py`.
# This file contains three simple functions:
#
# - `add(a, b)` – returns the sum of two numbers
# - `subtract(a, b)` – returns the difference
# - `multiply(a, b)` – returns the product
#
# These functions were created so they could be tested using the Python `unittest` module.

# %% [markdown]
# ## Writing Your First Test
# ---
#
# I created a second file called `test_calculator.py`.
# In this file, I imported the functions:
#
# ```python
# from calculator import add, subtract, multiply

# %% [markdown]
# ## Executing Your First Test
# To run the unit tests, I opened the terminal inside VS Code and typed:
#
# python test_calculator.py
#
# This command tells Python to execute the test file, discover the test methods, and display the results.

# %% [markdown]
# ## Test Results (Explained in My Own Words)
# When I ran the tests, the output was:
#
# Ran 3 tests in 0.000s
# OK
#
# This means:
#
# - Python successfully ran all three test methods
# - No errors or failures occurred
# - All of my functions (add, subtract, multiply) produced the correct results
# - The code is working as expected for the inputs I tested
#
# If any function returned the uninteded answer, the test output would show a failure message. Since the result says “OK,” all tests passed successfully.

# %% [markdown]
# ## Conclusion
# The unit testing process shows that my functions behave correctly. Using unittest ensured my code's accuraccy and
# helped verify the accuracy of my code and ensured that the logic works the way it should.
